# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime
from pprint import pprint
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create empty lists
name = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind_speed =[]

# %%
record_counter = 0
set_counter = 0




#URL for GET requests to retrieve data
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

print('Beginning Data Retrieval')
print('------------------------')
for city in cities:
    query_url = url + "&q=" + city
    
    #Get weather data
    
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0
    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))    
    
    try:
        name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind_speed.append(response['wind']['speed'])
        
#wait a second in loop to not over exceed limit of API

        time.sleep(1.01)
    
    except(KeyError):
        print(f'City not found.')
        pass
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | punta arenas
# Processing record 2 of set 0 | naryan-mar
# Processing record 3 of set 0 | coquimbo
# Processing record 4 of set 0 | faanui
# Processing record 5 of set 0 | new norfolk
# Processing record 6 of set 0 | tahe
# Processing record 7 of set 0 | longyearbyen
# Processing record 8 of set 0 | port alfred
# Processing record 9 of set 0 | nyurba
# Processing record 10 of set 0 | thompson
# Processing record 11 of set 0 | pisco
# Processing record 12 of set 0 | luderitz
# Processing record 13 of set 0 | ikom
# Processing record 14 of set 0 | olafsvik
# Processing record 15 of set 0 | jamestown
# Processing record 16 of set 0 | husavik
# Processing record 17 of set 0 | mys shmidta
# City not found.
# Processing record 18 of set 0 | kushiro
# Processing record 19 of set 0 | avarua
# Processing record 20 of set 0 | rikitea
# Processing record 21 of set 0 | mataura
# Processing record 22 of set 0 | lompoc
# Processing record 23 of set 0 | kahta
# Processing record 24 of set 0 | barrow
# Processing record 25 of set 0 | rawannawi
# City not found.
# Processing record 26 of set 0 | bagan
# Processing record 27 of set 0 | hermanus
# Processing record 28 of set 0 | bluff
# Processing record 29 of set 0 | albany
# Processing record 30 of set 0 | hilo
# Processing record 31 of set 0 | necochea
# Processing record 32 of set 0 | yarim
# Processing record 33 of set 0 | bethel
# Processing record 34 of set 0 | byron bay
# Processing record 35 of set 0 | palana
# Processing record 36 of set 0 | georgetown
# Processing record 37 of set 0 | loncoche
# Processing record 38 of set 0 | alofi
# Processing record 39 of set 0 | lebu
# Processing record 40 of set 0 | louisbourg
# City not found.
# Processing record 41 of set 0 | novouzensk
# Processing record 42 of set 0 | poum
# Processing record 43 of set 0 | tuktoyaktuk
# Processing record 44 of set 0 | sakakah
# Processing record 45 of set 0 | porbandar
# Processing record 46 of set 0 | williston
# Processing record 47 of set 0 | ushuaia
# Processing record 48 of set 0 | leningradskiy
# Processing record 49 of set 0 | manggar
# Processing record 50 of set 0 | nilakkottai
# Processing record 0 of set 1 | yellowknife
# Processing record 1 of set 1 | glace bay
# Processing record 2 of set 1 | coihaique
# Processing record 3 of set 1 | san bartolome de tirajana
# Processing record 4 of set 1 | russell
# Processing record 5 of set 1 | norman wells
# Processing record 6 of set 1 | viligili
# City not found.
# Processing record 7 of set 1 | pahrump
# Processing record 8 of set 1 | port elizabeth
# Processing record 9 of set 1 | illoqqortoormiut
# City not found.
# Processing record 10 of set 1 | gunjur
# Processing record 11 of set 1 | mitsamiouli
# Processing record 12 of set 1 | hovd
# Processing record 13 of set 1 | san patricio
# Processing record 14 of set 1 | parana
# Processing record 15 of set 1 | inyonga
# Processing record 16 of set 1 | cidreira
# Processing record 17 of set 1 | brookings
# Processing record 18 of set 1 | castro
# Processing record 19 of set 1 | praia da vitoria
# Processing record 20 of set 1 | marcona
# City not found.
# Processing record 21 of set 1 | ilulissat
# Processing record 22 of set 1 | vaitape
# Processing record 23 of set 1 | cape town
# Processing record 24 of set 1 | guarapari
# Processing record 25 of set 1 | ponta do sol
# Processing record 26 of set 1 | north port
# Processing record 27 of set 1 | vaitupu
# City not found.
# Processing record 28 of set 1 | hobart
# Processing record 29 of set 1 | neiafu
# Processing record 30 of set 1 | sambava
# Processing record 31 of set 1 | qaanaaq
# Processing record 32 of set 1 | kaitangata
# Processing record 33 of set 1 | taolanaro
# City not found.
# Processing record 34 of set 1 | vaini
# Processing record 35 of set 1 | nikolskoye
# Processing record 36 of set 1 | dongfeng
# Processing record 37 of set 1 | kavieng
# Processing record 38 of set 1 | urumqi
# Processing record 39 of set 1 | riyadh
# Processing record 40 of set 1 | abu samrah
# Processing record 41 of set 1 | tsihombe
# City not found.
# Processing record 42 of set 1 | avera
# Processing record 43 of set 1 | santa cruz de tenerife
# Processing record 44 of set 1 | cumaribo
# City not found.
# Processing record 45 of set 1 | tuatapere
# Processing record 46 of set 1 | preobrazhenka
# Processing record 47 of set 1 | anadyr
# Processing record 48 of set 1 | hasaki
# Processing record 49 of set 1 | cabedelo
# Processing record 50 of set 1 | ambanja
# Processing record 0 of set 2 | puerto ayora
# Processing record 1 of set 2 | bambous virieux
# Processing record 2 of set 2 | zabol
# Processing record 3 of set 2 | busselton
# Processing record 4 of set 2 | bredasdorp
# Processing record 5 of set 2 | skalistyy
# City not found.
# Processing record 6 of set 2 | linxia
# Processing record 7 of set 2 | kavaratti
# Processing record 8 of set 2 | grindavik
# Processing record 9 of set 2 | atuona
# Processing record 10 of set 2 | san luis
# Processing record 11 of set 2 | namatanai
# Processing record 12 of set 2 | kuche
# City not found.
# Processing record 13 of set 2 | lorengau
# Processing record 14 of set 2 | attawapiskat
# City not found.
# Processing record 15 of set 2 | tasiilaq
# Processing record 16 of set 2 | kapaa
# Processing record 17 of set 2 | cartagena
# Processing record 18 of set 2 | bajo baudo
# City not found.
# Processing record 19 of set 2 | bandarbeyla
# Processing record 20 of set 2 | qasigiannguit
# Processing record 21 of set 2 | komsomolskiy
# Processing record 22 of set 2 | tigil
# Processing record 23 of set 2 | muli
# Processing record 24 of set 2 | geraldton
# Processing record 25 of set 2 | grand river south east
# City not found.
# Processing record 26 of set 2 | vardo
# Processing record 27 of set 2 | namibe
# Processing record 28 of set 2 | airai
# Processing record 29 of set 2 | brewster
# Processing record 30 of set 2 | hithadhoo
# Processing record 31 of set 2 | carutapera
# Processing record 32 of set 2 | codrington
# Processing record 33 of set 2 | saskylakh
# Processing record 34 of set 2 | mandalgovi
# Processing record 35 of set 2 | saint-philippe
# Processing record 36 of set 2 | steamboat springs
# Processing record 37 of set 2 | narsaq
# Processing record 38 of set 2 | aquiraz
# Processing record 39 of set 2 | tonbridge
# Processing record 40 of set 2 | carnarvon
# Processing record 41 of set 2 | tarare
# Processing record 42 of set 2 | puerto del rosario
# Processing record 43 of set 2 | richards bay
# Processing record 44 of set 2 | hay river
# Processing record 45 of set 2 | berezovka
# Processing record 46 of set 2 | kununurra
# Processing record 47 of set 2 | bairiki
# Processing record 48 of set 2 | lagoa
# Processing record 49 of set 2 | dikson
# Processing record 50 of set 2 | deyang
# Processing record 0 of set 3 | mar del plata
# Processing record 1 of set 3 | haines junction
# Processing record 2 of set 3 | mahebourg
# Processing record 3 of set 3 | nizhneyansk
# City not found.
# Processing record 4 of set 3 | hare bay
# Processing record 5 of set 3 | warrington
# Processing record 6 of set 3 | pachino
# Processing record 7 of set 3 | yar-sale
# Processing record 8 of set 3 | coahuayana
# Processing record 9 of set 3 | cap malheureux
# Processing record 10 of set 3 | inderborskiy
# City not found.
# Processing record 11 of set 3 | vaovai
# City not found.
# Processing record 12 of set 3 | cesvaine
# Processing record 13 of set 3 | tecoanapa
# Processing record 14 of set 3 | arraial do cabo
# Processing record 15 of set 3 | uvat
# Processing record 16 of set 3 | eucaliptus
# Processing record 17 of set 3 | nolinsk
# Processing record 18 of set 3 | aflu
# City not found.
# Processing record 19 of set 3 | henderson
# Processing record 20 of set 3 | matara
# Processing record 21 of set 3 | vung tau
# Processing record 22 of set 3 | beloha
# Processing record 23 of set 3 | palabuhanratu
# City not found.
# Processing record 24 of set 3 | lasa
# Processing record 25 of set 3 | flinders
# Processing record 26 of set 3 | porto novo
# Processing record 27 of set 3 | koulikoro
# Processing record 28 of set 3 | esperance
# Processing record 29 of set 3 | yurginskoye
# Processing record 30 of set 3 | samusu
# City not found.
# Processing record 31 of set 3 | kysyl-syr
# Processing record 32 of set 3 | mamakan
# Processing record 33 of set 3 | coruripe
# Processing record 34 of set 3 | saint-augustin
# Processing record 35 of set 3 | butaritari
# Processing record 36 of set 3 | victoria
# Processing record 37 of set 3 | vila
# Processing record 38 of set 3 | pacific grove
# Processing record 39 of set 3 | krasnoznamensk
# Processing record 40 of set 3 | kruisfontein
# Processing record 41 of set 3 | laguna
# Processing record 42 of set 3 | bayir
# Processing record 43 of set 3 | omsukchan
# Processing record 44 of set 3 | mariental
# Processing record 45 of set 3 | amderma
# City not found.
# Processing record 46 of set 3 | siavonga
# Processing record 47 of set 3 | vila velha
# Processing record 48 of set 3 | aswan
# Processing record 49 of set 3 | namalenga
# Processing record 50 of set 3 | umarkot
# Processing record 0 of set 4 | atyuryevo
# City not found.
# Processing record 1 of set 4 | margate
# Processing record 2 of set 4 | berlevag
# Processing record 3 of set 4 | tiksi
# Processing record 4 of set 4 | touros
# Processing record 5 of set 4 | xuddur
# Processing record 6 of set 4 | parva
# Processing record 7 of set 4 | batemans bay
# Processing record 8 of set 4 | falun
# Processing record 9 of set 4 | saint-louis
# Processing record 10 of set 4 | bhatkal
# Processing record 11 of set 4 | chokurdakh
# Processing record 12 of set 4 | pocatello
# Processing record 13 of set 4 | meyungs
# City not found.
# Processing record 14 of set 4 | khatanga
# Processing record 15 of set 4 | talas
# Processing record 16 of set 4 | port hawkesbury
# Processing record 17 of set 4 | ambodifototra
# City not found.
# Processing record 18 of set 4 | aklavik
# Processing record 19 of set 4 | bara
# Processing record 20 of set 4 | chiang klang
# Processing record 21 of set 4 | kjopsvik
# Processing record 22 of set 4 | shar
# Processing record 23 of set 4 | elizabeth city
# Processing record 24 of set 4 | barentsburg
# City not found.
# Processing record 25 of set 4 | kahului
# Processing record 26 of set 4 | saint anthony
# Processing record 27 of set 4 | uyskoye
# Processing record 28 of set 4 | sentyabrskiy
# City not found.
# Processing record 29 of set 4 | fairbanks
# Processing record 30 of set 4 | kokologo
# Processing record 31 of set 4 | nizhniy chir
# Processing record 32 of set 4 | finschhafen
# Processing record 33 of set 4 | sainte-marie
# Processing record 34 of set 4 | mchinji
# Processing record 35 of set 4 | severo-kurilsk
# Processing record 36 of set 4 | requena
# Processing record 37 of set 4 | sao filipe
# Processing record 38 of set 4 | petropavlovsk-kamchatskiy
# Processing record 39 of set 4 | marienburg
# Processing record 40 of set 4 | vao
# Processing record 41 of set 4 | puerto escondido
# Processing record 42 of set 4 | provideniya
# Processing record 43 of set 4 | krasnoselkup
# Processing record 44 of set 4 | burriana
# Processing record 45 of set 4 | ostrovnoy
# Processing record 46 of set 4 | isangel
# Processing record 47 of set 4 | kihei
# Processing record 48 of set 4 | souillac
# Processing record 49 of set 4 | ambulu
# Processing record 50 of set 4 | paka
# Processing record 0 of set 5 | inverell
# Processing record 1 of set 5 | anchorage
# Processing record 2 of set 5 | neuquen
# Processing record 3 of set 5 | yamada
# Processing record 4 of set 5 | santa maria
# Processing record 5 of set 5 | ocampo
# Processing record 6 of set 5 | te anau
# Processing record 7 of set 5 | kaiwaka
# Processing record 8 of set 5 | maues
# Processing record 9 of set 5 | tromso
# Processing record 10 of set 5 | salalah
# Processing record 11 of set 5 | karratha
# Processing record 12 of set 5 | sungaipenuh
# Processing record 13 of set 5 | caramay
# Processing record 14 of set 5 | skiros
# City not found.
# Processing record 15 of set 5 | mehamn
# Processing record 16 of set 5 | dingle
# Processing record 17 of set 5 | metro
# Processing record 18 of set 5 | glenwood springs
# Processing record 19 of set 5 | severomuysk
# Processing record 20 of set 5 | upernavik
# Processing record 21 of set 5 | rio grande
# Processing record 22 of set 5 | amahai
# Processing record 23 of set 5 | paliyad
# Processing record 24 of set 5 | nalut
# Processing record 25 of set 5 | skjervoy
# Processing record 26 of set 5 | caravelas
# Processing record 27 of set 5 | daru
# Processing record 28 of set 5 | lavrentiya
# Processing record 29 of set 5 | creel
# Processing record 30 of set 5 | comodoro rivadavia
# Processing record 31 of set 5 | artyom
# Processing record 32 of set 5 | aksu
# Processing record 33 of set 5 | zhigansk
# Processing record 34 of set 5 | kousseri
# Processing record 35 of set 5 | jalu
# Processing record 36 of set 5 | tessalit
# Processing record 37 of set 5 | mezen
# Processing record 38 of set 5 | pangody
# Processing record 39 of set 5 | cabo san lucas
# Processing record 40 of set 5 | pontes e lacerda
# Processing record 41 of set 5 | tonantins
# Processing record 42 of set 5 | umba
# Processing record 43 of set 5 | karamea
# City not found.
# Processing record 44 of set 5 | chalus
# Processing record 45 of set 5 | bolungarvik
# City not found.
# Processing record 46 of set 5 | arecibo
# Processing record 47 of set 5 | umm lajj
# Processing record 48 of set 5 | talnakh
# Processing record 49 of set 5 | makueni
# Processing record 50 of set 5 | san jacinto
# Processing record 0 of set 6 | macusani
# Processing record 1 of set 6 | vagay
# Processing record 2 of set 6 | deleni
# Processing record 3 of set 6 | nouadhibou
# Processing record 4 of set 6 | yishui
# Processing record 5 of set 6 | tanout
# Processing record 6 of set 6 | paragominas
# Processing record 7 of set 6 | east london
# Processing record 8 of set 6 | simoes
# Processing record 9 of set 6 | eirunepe
# Processing record 10 of set 6 | deputatskiy
# Processing record 11 of set 6 | kot addu
# Processing record 12 of set 6 | ribeira grande
# Processing record 13 of set 6 | saint george
# Processing record 14 of set 6 | suining
# Processing record 15 of set 6 | mountain home
# Processing record 16 of set 6 | kudahuvadhoo
# Processing record 17 of set 6 | goure
# Processing record 18 of set 6 | birjand
# Processing record 19 of set 6 | piacabucu
# Processing record 20 of set 6 | maniitsoq
# Processing record 21 of set 6 | ruthin
# Processing record 22 of set 6 | moron
# Processing record 23 of set 6 | kendari
# Processing record 24 of set 6 | korla
# Processing record 25 of set 6 | belaya gora
# Processing record 26 of set 6 | pimenta bueno
# Processing record 27 of set 6 | fare
# Processing record 28 of set 6 | andrelandia
# Processing record 29 of set 6 | cherskiy
# Processing record 30 of set 6 | clyde river
# Processing record 31 of set 6 | doha
# Processing record 32 of set 6 | alyangula
# Processing record 33 of set 6 | karlskrona
# Processing record 34 of set 6 | fortuna
# Processing record 35 of set 6 | pandan
# Processing record 36 of set 6 | dakar
# Processing record 37 of set 6 | dolores
# Processing record 38 of set 6 | phan thiet
# Processing record 39 of set 6 | makushino
# Processing record 40 of set 6 | sorland
# Processing record 41 of set 6 | tselinnoye
# Processing record 42 of set 6 | porto santo
# Processing record 43 of set 6 | kuzovatovo
# Processing record 44 of set 6 | college
# Processing record 45 of set 6 | vangaindrano
# Processing record 46 of set 6 | torbay
# Processing record 47 of set 6 | luang prabang
# Processing record 48 of set 6 | benguela
# Processing record 49 of set 6 | tabory
# Processing record 50 of set 6 | hemnesberget
# Processing record 0 of set 7 | pajapan
# Processing record 1 of set 7 | thinadhoo
# Processing record 2 of set 7 | gallup
# Processing record 3 of set 7 | mnogovershinnyy
# Processing record 4 of set 7 | igualada
# Processing record 5 of set 7 | kalmunai
# Processing record 6 of set 7 | torbat-e jam
# Processing record 7 of set 7 | paamiut
# Processing record 8 of set 7 | iwata
# Processing record 9 of set 7 | villazon
# Processing record 10 of set 7 | vawkavysk
# Processing record 11 of set 7 | hermiston
# Processing record 12 of set 7 | rudbar
# Processing record 13 of set 7 | cocorna
# Processing record 14 of set 7 | kodiak
# Processing record 15 of set 7 | tumannyy
# City not found.
# Processing record 16 of set 7 | prado
# Processing record 17 of set 7 | iraucuba
# Processing record 18 of set 7 | yenagoa
# Processing record 19 of set 7 | raga
# Processing record 20 of set 7 | puerto madryn
# Processing record 21 of set 7 | san javier
# Processing record 22 of set 7 | ahipara
# Processing record 23 of set 7 | safford
# Processing record 24 of set 7 | terrace bay
# Processing record 25 of set 7 | pochutla
# Processing record 26 of set 7 | laureles
# Processing record 27 of set 7 | casper
# Processing record 28 of set 7 | buchanan
# Processing record 29 of set 7 | saleaula
# City not found.
# Processing record 30 of set 7 | ushtobe
# Processing record 31 of set 7 | naze
# Processing record 32 of set 7 | emirdag
# Processing record 33 of set 7 | turukhansk
# Processing record 34 of set 7 | nanortalik
# Processing record 35 of set 7 | mahanje
# Processing record 36 of set 7 | farafangana
# Processing record 37 of set 7 | columbus
# Processing record 38 of set 7 | omboue
# Processing record 39 of set 7 | northam
# Processing record 40 of set 7 | ekhabi
# Processing record 41 of set 7 | axim
# Processing record 42 of set 7 | gamba
# Processing record 43 of set 7 | marsaxlokk
# Processing record 44 of set 7 | lerwick
# Processing record 45 of set 7 | belushya guba
# City not found.
# Processing record 46 of set 7 | betioky
# Processing record 47 of set 7 | namie
# Processing record 48 of set 7 | san cristobal
# Processing record 49 of set 7 | port lincoln
# Processing record 50 of set 7 | kampot
# Processing record 0 of set 8 | baykit
# Processing record 1 of set 8 | kharagauli
# Processing record 2 of set 8 | port-gentil
# Processing record 3 of set 8 | pevek
# Processing record 4 of set 8 | tabou
# Processing record 5 of set 8 | sao joao da barra
# Processing record 6 of set 8 | tambura
# Processing record 7 of set 8 | mount gambier
# Processing record 8 of set 8 | karaul
# City not found.
# Processing record 9 of set 8 | kerema
# Processing record 10 of set 8 | beringovskiy
# Processing record 11 of set 8 | camacha
# Processing record 12 of set 8 | honiara
# Processing record 13 of set 8 | phalombe
# Processing record 14 of set 8 | kloulklubed
# Processing record 15 of set 8 | shingu
# Processing record 16 of set 8 | marawi
# Processing record 17 of set 8 | lomovka
# Processing record 18 of set 8 | devils lake
# Processing record 19 of set 8 | sitka
# Processing record 20 of set 8 | mapua
# Processing record 21 of set 8 | ye
# City not found.
# Processing record 22 of set 8 | pembroke
# Processing record 23 of set 8 | bundaberg
# Processing record 24 of set 8 | utiroa
# City not found.
# Processing record 25 of set 8 | helong
# Processing record 26 of set 8 | alvaraes
# Processing record 27 of set 8 | kenai
# Processing record 28 of set 8 | belmonte
# Processing record 29 of set 8 | akyab
# Processing record 30 of set 8 | abakaliki
# Processing record 31 of set 8 | macaboboni
# City not found.
# Processing record 32 of set 8 | shache
# Processing record 33 of set 8 | yulara
# Processing record 34 of set 8 | remontnoye
# Processing record 35 of set 8 | lima
# Processing record 36 of set 8 | trincomalee
# Processing record 37 of set 8 | sao felix do xingu
# Processing record 38 of set 8 | turek
# Processing record 39 of set 8 | sibolga
# Processing record 40 of set 8 | port blair
# Processing record 41 of set 8 | zhezkazgan
# Processing record 42 of set 8 | schifferstadt
# Processing record 43 of set 8 | khandyga
# Processing record 44 of set 8 | kaspiysk
# Processing record 45 of set 8 | pavagada
# Processing record 46 of set 8 | hurghada
# Processing record 47 of set 8 | wulanhaote
# City not found.
# Processing record 48 of set 8 | eldikan
# City not found.
# Processing record 49 of set 8 | sur
# Processing record 50 of set 8 | port hardy
# Processing record 0 of set 9 | vanderbijlpark
# Processing record 1 of set 9 | wakkanai
# Processing record 2 of set 9 | fukue
# Processing record 3 of set 9 | colares
# Processing record 4 of set 9 | dubai
# Processing record 5 of set 9 | saint-andre-les-vergers
# Processing record 6 of set 9 | christchurch
# Processing record 7 of set 9 | tiznit
# Processing record 8 of set 9 | tucuma
# Processing record 9 of set 9 | chulman
# Processing record 10 of set 9 | emilio carranza
# Processing record 11 of set 9 | moose factory
# Processing record 12 of set 9 | claudio
# Processing record 13 of set 9 | birao
# Processing record 14 of set 9 | bur gabo
# City not found.
# Processing record 15 of set 9 | guerrero negro
# Processing record 16 of set 9 | chilca
# Processing record 17 of set 9 | chuy
# Processing record 18 of set 9 | ayer itam
# City not found.
# Processing record 19 of set 9 | kuching
# Processing record 20 of set 9 | sioux lookout
# Processing record 21 of set 9 | vila franca do campo
# Processing record 22 of set 9 | katherine
# Processing record 23 of set 9 | bambanglipuro
# Processing record 24 of set 9 | yaan
# Processing record 25 of set 9 | madras
# Processing record 26 of set 9 | the valley
# Processing record 27 of set 9 | coracora
# Processing record 28 of set 9 | slavutych
# Processing record 29 of set 9 | marsa matruh
# Processing record 30 of set 9 | saldanha
# Processing record 31 of set 9 | sinnamary
# Processing record 32 of set 9 | ayagoz
# Processing record 33 of set 9 | turochak
# Processing record 34 of set 9 | tome-acu
# City not found.
# Processing record 35 of set 9 | nemuro
# Processing record 36 of set 9 | baghdad
# Processing record 37 of set 9 | ailigandi
# Processing record 38 of set 9 | bukama
# Processing record 39 of set 9 | paita
# Processing record 40 of set 9 | willowmore
# Processing record 41 of set 9 | manaia
# Processing record 42 of set 9 | carauari
# Processing record 43 of set 9 | biharkeresztes
# Processing record 44 of set 9 | new bern
# Processing record 45 of set 9 | palmer
# Processing record 46 of set 9 | iqaluit
# Processing record 47 of set 9 | panaba
# Processing record 48 of set 9 | orlik
# Processing record 49 of set 9 | san felipe
# Processing record 50 of set 9 | uray
# Processing record 0 of set 10 | dinguiraye
# Processing record 1 of set 10 | makasar
# Processing record 2 of set 10 | pavlodar
# Processing record 3 of set 10 | burnie
# Processing record 4 of set 10 | shimonoseki
# Processing record 5 of set 10 | virginia beach
# Processing record 6 of set 10 | rovaniemi
# Processing record 7 of set 10 | hamilton
# Processing record 8 of set 10 | talara
# Processing record 9 of set 10 | synya
# Processing record 10 of set 10 | togur
# Processing record 11 of set 10 | molina
# Processing record 12 of set 10 | miandrivazo
# Processing record 13 of set 10 | minsk
# Processing record 14 of set 10 | pangoa
# Processing record 15 of set 10 | yunjinghong
# City not found.
# Processing record 16 of set 10 | ancud
# Processing record 17 of set 10 | boa vista
# Processing record 18 of set 10 | karpathos
# Processing record 19 of set 10 | sao luis do quitunde
# Processing record 20 of set 10 | bahile
# Processing record 21 of set 10 | bengkulu
# Processing record 22 of set 10 | srednekolymsk
# Processing record 23 of set 10 | mentok
# City not found.
# Processing record 24 of set 10 | lolua
# City not found.
# Processing record 25 of set 10 | thanh hoa
# Processing record 26 of set 10 | tautira
# Processing record 27 of set 10 | kailua
# Processing record 28 of set 10 | huarmey
# Processing record 29 of set 10 | arman
# Processing record 30 of set 10 | qaqortoq
# Processing record 31 of set 10 | bahia blanca
# Processing record 32 of set 10 | la ronge
# Processing record 33 of set 10 | zachary
# Processing record 34 of set 10 | moindou
# Processing record 35 of set 10 | whitehorse
# Processing record 36 of set 10 | yelizovo
# Processing record 37 of set 10 | cayenne
# Processing record 38 of set 10 | hualmay
# Processing record 39 of set 10 | ust-tsilma
# Processing record 40 of set 10 | guatire
# Processing record 41 of set 10 | berezniki
# Processing record 42 of set 10 | katsuura
# Processing record 43 of set 10 | parkes
# Processing record 44 of set 10 | selvazzano dentro
# Processing record 45 of set 10 | banjar
# Processing record 46 of set 10 | liverpool
# Processing record 47 of set 10 | broken hill
# Processing record 48 of set 10 | bathsheba
# Processing record 49 of set 10 | vincennes
# Processing record 50 of set 10 | shimoda
# Processing record 0 of set 11 | kiama
# Processing record 1 of set 11 | vilyuysk
# Processing record 2 of set 11 | hvittingfoss
# Processing record 3 of set 11 | vigrestad
# Processing record 4 of set 11 | ust-barguzin
# Processing record 5 of set 11 | harrismith
# Processing record 6 of set 11 | yankton
# Processing record 7 of set 11 | half moon bay
# Processing record 8 of set 11 | ondorhaan
# City not found.
# Processing record 9 of set 11 | okha
# Processing record 10 of set 11 | manadhoo
# Processing record 11 of set 11 | ndele
# Processing record 12 of set 11 | samana
# Processing record 13 of set 11 | rayon
# Processing record 14 of set 11 | calabar
# Processing record 15 of set 11 | aykhal
# Processing record 16 of set 11 | hauterive
# Processing record 17 of set 11 | coromandel
# Processing record 18 of set 11 | tawnat
# City not found.
# Processing record 19 of set 11 | kangaatsiaq
# Processing record 20 of set 11 | sisimiut
# Processing record 21 of set 11 | evensk
# Processing record 22 of set 11 | edd
# Processing record 23 of set 11 | dipkarpaz
# City not found.
# Processing record 24 of set 11 | raul soares
# Processing record 25 of set 11 | verkhnyaya toyma
# Processing record 26 of set 11 | zolotinka
# City not found.
# Processing record 27 of set 11 | sorvag
# City not found.
# Processing record 28 of set 11 | walvis bay
# Processing record 29 of set 11 | kenora
# Processing record 30 of set 11 | san andres
# Processing record 31 of set 11 | paraiso
# Processing record 32 of set 11 | borgomanero
# Processing record 33 of set 11 | marystown
# Processing record 34 of set 11 | constitucion
# Processing record 35 of set 11 | buritis
# Processing record 36 of set 11 | saveh
# Processing record 37 of set 11 | dzhebariki-khaya
# Processing record 38 of set 11 | pemba
# Processing record 39 of set 11 | kidal
# Processing record 40 of set 11 | katangli
# Processing record 41 of set 11 | kamenka
# Processing record 42 of set 11 | garowe
# Processing record 43 of set 11 | sandane
# Processing record 44 of set 11 | klaksvik
# Processing record 45 of set 11 | cockburn town
# Processing record 46 of set 11 | san jose
# Processing record 47 of set 11 | usinsk
# Processing record 48 of set 11 | lyuban
# Processing record 49 of set 11 | carbonia
# Processing record 50 of set 11 | cururupu
# Processing record 0 of set 12 | muskegon
# Processing record 1 of set 12 | leh
# Processing record 2 of set 12 | portlethen
# Processing record 3 of set 12 | lahij
# Processing record 4 of set 12 | fayaoue
# Processing record 5 of set 12 | teguise
# Processing record 6 of set 12 | saint-georges
# Processing record 7 of set 12 | catio
# Processing record 8 of set 12 | clonakilty
# Processing record 9 of set 12 | los llanos de aridane
# Processing record 10 of set 12 | luau
# Processing record 11 of set 12 | miramar
# Processing record 12 of set 12 | churapcha
# Processing record 13 of set 12 | blagoyevo
# Processing record 14 of set 12 | tezu
# Processing record 15 of set 12 | dandong
# Processing record 16 of set 12 | salvador
# Processing record 17 of set 12 | kimbe
# Processing record 18 of set 12 | morris
# Processing record 19 of set 12 | casino
# Processing record 20 of set 12 | hillsborough
# Processing record 21 of set 12 | tabas
# Processing record 22 of set 12 | ornskoldsvik
# Processing record 23 of set 12 | chimbote
# Processing record 24 of set 12 | lodja
# Processing record 25 of set 12 | tavira
# Processing record 26 of set 12 | yatou

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#export city data into csv
#make dictionary of lists

# dictionary of lists   
weather_dict = {'City': name, 'Cloudiness': cloudiness, 'Country': country, 'Date': date, 'Humidity': humidity, 'Temperature': temp, 'Latitude': lat, 'Longitude': lng, 'Wind Speed': wind_speed}   
       

city_df = pd.DataFrame(weather_dict)  

city_df


   
# saving the dataframe  
city_df.to_csv("../output_data/cities(out).csv")

# %%
# Use describe to get the max and see if its above 100 for humidity 
city_df.describe()
# Out:
#        Cloudiness          Date    Humidity  Temperature    Latitude  \
# count  588.000000  5.880000e+02  588.000000   588.000000  588.000000
# mean    53.897959  1.612553e+09   72.906463    50.222908   20.825265
# std     40.675428  2.040991e+02   20.690790    33.141446   33.623447
# min      0.000000  1.612552e+09   11.000000   -42.570000  -54.800000
# 25%      3.000000  1.612553e+09   65.000000    30.200000   -7.686675
# 50%     72.000000  1.612553e+09   78.000000    61.015000   25.674450
# 75%     97.000000  1.612553e+09   88.000000    77.485000   49.887550
# max    100.000000  1.612553e+09  100.000000    98.600000   78.218600
#
#         Longitude  Wind Speed
# count  588.000000  588.000000
# mean    16.302480    8.448146
# std     89.476576    5.731192
# min   -175.200000    0.270000
# 25%    -60.098700    4.052500
# 50%     19.130550    6.910000
# 75%     85.786750   11.525000
# max    179.316700   38.030000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
if len(city_df.loc[city_df["Humidity"] >= 100]) > 0:
    clean_city_df = pd.DataFrame.copy(city_df).drop(city_df.loc[city_df["Humidity"] >100].index)
else:
    clean_city_df = pd.DataFrame.copy(city_df)

# print out lenghts of original and clean data to see if the values were dropped or not 
len(city_df), len(clean_city_df)
# Out:
# (588, 588)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_df.plot(kind='scatter', x='Latitude', y='Temperature', c='LightSkyBlue', edgecolor='black')
plt.title('City Latitude vs. Temperature '+ datetime.date.fromtimestamp(clean_city_df["Date"][0]).strftime("%m/%d/%y"))
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(color='lightgrey',
               alpha=0.5)
plt.savefig("../output_data/City Latitude vs. Temperature.png")

# %% [markdown]
# * As latitude increases, temperature decreases, showing that temperatures are usually colder in cities north of the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_df.plot(kind='scatter', x='Latitude', y='Humidity', c='LightGreen', edgecolor='black')
plt.title('City Latitude vs. Humidity '+ datetime.date.fromtimestamp(clean_city_df["Date"][0]).strftime("%m/%d/%y"))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)') 
plt.grid(color='lightgrey',
               alpha=0.5)
plt.savefig("../output_data/City Latitude vs. Humidity.png")

# %% [markdown]
# * Humidity levels show more variance at the equator and southern hempisphere. As latitude increases north of the equator, humidity also increases.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_df.plot(kind='scatter', x='Latitude', y='Cloudiness', c='Pink', edgecolor='black')
plt.title('City Latitude vs. Cloudiness '+ datetime.date.fromtimestamp(clean_city_df["Date"][0]).strftime("%m/%d/%y"))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)') 
plt.grid(color='lightgrey',
               alpha=0.5)
plt.savefig("../output_data/City Latitude vs. Cloudiness.png")

# %% [markdown]
# * The effect of latitude on cloudiness greatly varies.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_df.plot(kind='scatter',x='Latitude',y='Wind Speed', c='Blue', edgecolor = "black")
plt.title('City Latitude vs. Wind Speed '+ datetime.date.fromtimestamp(clean_city_df["Date"][0]).strftime("%m/%d/%y"))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(color='lightgrey',
               alpha=0.5)
plt.savefig("../output_data/City Latitude vs. Wind Speed.png")

# %% [markdown]
# * Wind speed varies greatly across latitudes. There are notable outliers in wind speeds as latitudes approach extremities of the North and South Poles.

# %% [markdown]
# ## Linear Regression

# %%
#Break up northern and southern hemispheres
north_hem = clean_city_df.loc[clean_city_df["Latitude"] > 0]
south_hem = clean_city_df.loc[clean_city_df["Latitude"]< 0]

# %%
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Latitude"], north_hem["Temperature"])
annotate(equation, 0, -20)

plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Latitude"], south_hem["Temperature"])
annotate(equation, -40, 50)

plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.48

# %% [markdown]
# * In the Northern hempishere, max temperatures decrease as latitudes increase. In the Southern hemisphere, max temperatures are positively correlated with latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Latitude"], north_hem["Humidity"])
annotate(equation, 40, 10)

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.41

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Latitude"], south_hem["Humidity"])
annotate(equation, -25, 40)

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.14

# %% [markdown]
# *There is a positive correlation between latitude and humidity in both the Northern and Southern hemispheres, though this correlation is less strong in the Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Latitude"], north_hem["Cloudiness"])
annotate(equation, 38, 29)

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.29

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Latitude"], south_hem["Cloudiness"])
annotate(equation, -48, 63)

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# *There is a positive correlation between cloudiness and latitude in both the Northern and Southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Latitude"], north_hem["Wind Speed"])
annotate(equation, 5, 32)

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.01

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Latitude"], south_hem["Wind Speed"])
annotate(equation, -55, 22)

plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.12

# %% [markdown]
# *There are minimal correlations between wind speed and latitude.
